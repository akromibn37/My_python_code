# %%
import requests
from bs4 import BeautifulSoup
l=[]
base_url="http://www.priceza.com/search?category=0&brand=Apple&page="
con="&sort=1&productdataname=iphone%206s"
for page in range(1,100,1):
    print(base_url+str(page)+con)
    r=requests.get(base_url+str(page)+con)
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class","grid-box"})
    all2=soup.find_all("div",{"class","pd-info"})
    for i,j in zip(all,all2):
        d={}
        d["Product name"]=i.find_all("h3",{"itemprop":"name"})[0].text
        try:
            d["Price"]=i.find_all("span",{"itemprop":"price"})[0].text.replace("฿","").replace("\n","")
        except:
            d["Price"]=None
        d["Description"]=j.find("span",{"itemprop":"description"}).text.replace("\t","").replace("\n","").replace("\r","")
    #     d["Battery"]=k.find_all("li")[0].text.replace("Battery: ","")
    #     d["Camera"]=k.find_all("li")[1].text.replace("Camera: ","")
    #     d["Screen"]=k.find_all("li")[2].text.replace("Screen Size: ","")
    #     d["Storage"]=k.find_all("li")[3].text.replace("Storage: ","")   
        l.append(d)
len(l)
# Out:
# http://www.priceza.com/search?category=0&brand=Apple&page=1&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=2&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=3&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=4&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=5&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=6&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=7&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=8&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=9&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=10&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=11&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=12&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=13&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=14&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=15&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=16&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=17&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=18&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=19&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=20&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=21&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=22&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=23&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=24&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=25&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=26&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=27&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=28&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=29&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=30&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=31&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=32&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=33&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=34&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=35&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=36&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=37&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=38&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=39&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=40&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=41&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=42&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=43&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=44&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=45&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=46&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=47&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=48&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=49&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=50&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=51&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=52&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=53&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=54&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=55&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=56&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=57&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=58&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=59&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=60&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=61&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=62&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=63&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=64&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=65&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=66&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=67&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=68&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=69&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=70&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=71&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=72&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=73&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=74&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=75&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=76&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=77&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=78&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=79&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=80&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=81&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=82&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=83&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=84&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=85&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=86&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=87&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=88&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=89&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=90&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=91&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=92&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=93&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=94&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=95&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=96&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=97&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=98&sort=1&productdataname=iphone%206s
# http://www.priceza.com/search?category=0&brand=Apple&page=99&sort=1&productdataname=iphone%206s
# 2095

# %%
import pandas
df=pandas.DataFrame(l)
df
df.to_csv("output_priceza_multiple_page.csv")
